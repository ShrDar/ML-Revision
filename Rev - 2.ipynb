# %% [markdown]
# # Matplotlib and Seaborn

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Matplotlib Basic Intro

# %%
# Matplotlib => It's a python library used for data visualization.
# It helps in turining data into charts, bar charts, histograms, scatter plots and so on

# %%
x = np.array([2023, 2024, 2025, 2026, 2027])
y = np.array([12, 20, 35, 40, 42])

plt.plot(x, y) #if one argument is not given the y will be the default argument and x will be supposed as 0 to the number of values in y with increment of 1 in the x coordinate
plt.show()

# %%
year = np.array([2020, 2021, 2022, 2023, 2024, 2025, 2026])
chelTrophies = np.array([1, 3, 0, 2, 1, 2, 0])

plt.plot(year, chelTrophies)
plt.show()

# %% [markdown]
# ### Plot Customization

# %%
x = np.array([2023, 2024, 2025, 2026])
y1 = np.array([15, 24, 30, 20])
y2 = np.array([2, 10, 40, 30])
y3 = np.array([20, 50, 80, 120])

line_style = dict(marker = ".", #dict() changes the something = smthvalue to dictionary key value pair
                markersize = 15, # shorthand => ms
                markerfacecolor = "#FB9393", # => mfc
                markeredgecolor = "#000000", # => mec
                linestyle = "dotted",
                linewidth = 2)

plt.plot(x, y1, **line_style, color = "#ED8631") # solid, dashdot, dotted, None (** => unpack to original state)

plt.plot(x, y2, **line_style, color = "#000000")

plt.plot(x, y3, **line_style, color = "#009043")


plt.show()

# %% [markdown]
# ### Labels

# %%
x = np.array([2023, 2024, 2025, 2026])
y1 = np.array([15, 24, 30, 20])
y2 = np.array([2, 10, 40, 30])
y3 = np.array([20, 50, 80, 120])

line_style = dict(marker = ".", #dict() changes the something = smthvalue to dictionary key value pair
                markersize = 15, # shorthand => ms
                markerfacecolor = "#FB9393", # => mfc
                markeredgecolor = "#000000", # => mec
                linestyle = "solid", # solid, dashdot, dotted, None (** => unpack to original state)
                linewidth = 2)

plt.title("Class Size", fontsize = 15, 
                        family = "Arial",
                        fontweight = "bold",
                        color = "#565656")
plt.xlabel("Year", fontsize = 14, 
                    fontweight = "bold",
                    color = "#565656")
plt.ylabel("No. of Students", fontsize = 14, 
                    fontweight = "bold",
                    color = "#565656")
plt.tick_params(axis = "both", 
                colors = "#3A3A3A")

plt.plot(x, y1, **line_style, color = "#ED8631") 

plt.plot(x, y2, **line_style, color = "#000000")

plt.plot(x, y3, **line_style, color = "#009043")

plt.xticks(x)


plt.show()

# %% [markdown]
# ### Grid Lines

# %%
# grid() => helps in making plots easier to read by adding reference lines.

x = np.array([1, 2, 3, 4, 5])
y = np.array([20, 30, 40, 50, 90])


plt.plot(x, y, marker = ".", 
                markersize = 20, 
                markeredgecolor = "#515151", 
                markerfacecolor = "#2A2A2A",
                color = "#000000")

plt.grid(axis="both", 
         visible=None,
         linewidth = 1,
         color = "#000000",
         linestyle = "dotted")

plt.xticks(x)

plt.title("Grid Lines Demo")
plt.xlabel("No. of Guns")
plt.ylabel("No of Deaths")

plt.show()

# %% [markdown]
# ### Bar Charts

# %%
# Bar Chart => compares categories of data by representing each category with a bar

categories = ["Grains", "Fruits", "Veggies", "Protein", "Dairy", "Sweets"]
values = np.array([4, 3, 2, 5, 2, 1])

# plt.bar(categories, values, color = "#f3d57b")
plt.barh(categories, values, color = "#f3d57b")


plt.title("Daily Food Consumption")
plt.xlabel("Food")
plt.ylabel("Quantity")

plt.show()

# %% [markdown]
# ### Pie-Charts

# %%
# Pie-Chart => Circular chart divided into slices to show percentages of the total.
# Good for visualizing distribution among categores

categories = ["Freshmen", "Sophomores", "Juniors", "Seniors"]
values = np.array([300, 250, 275, 225])
colors = ["#9469B5", "#ffacac", "#fff7a1", "#a5baff"]

plt.pie(values, labels=categories, 
                autopct="%1.1f%%",
                colors = colors,
                explode=[0, 0, 0, 0.1],
                shadow = True,
                startangle=70)

plt.title("College Student Category Distribution")
plt.show()

# %% [markdown]
# ### Scatter Graph/Plot

# %%
# Scatter Graph => Shows relationship between variables 
# Helps to identify a correlation (+, -, None)
# Example: Study hours and Test Scores

x1 = np.array([0, 1, 1, 2, 3, 4, 5, 6, 7, 7, 9])
y1 = np.array([39, 57, 59, 60, 68, 75, 77, 78, 79, 82, 91])

x2 = np.array([0, 1, 2, 3, 3, 4, 5, 8, 9, 10, 11])
y2 = np.array([10, 20, 42, 50, 55, 66, 75, 79, 88, 90, 92])

plt.scatter(x1, y1, color = "#000000", 
                    alpha = 0.5,
                    s = 100, 
                    edgecolors="000000", 
                    label = "Class A")

plt.scatter(x2, y2, color = "#4AB2B0", 
                    s = 90, 
                    alpha=0.7,
                    edgecolor="#694800",
                    label = "Class B")

plt.title("Scatter Plot of Study Hours Vs Test Scores")
plt.xlabel("Hours")
plt.ylabel("Test Scores")

plt.legend()
plt.show()

# %% [markdown]
# ### Histograms

# %%
# Histogram => Visual Representation of the distribution of quantitative data
# They group values into bins (intervals)
# and counts how many fall in each range


scores = np.random.normal(loc = 80, scale = 10, size = 100)
scores = np.clip(scores, 0, 100)

plt.hist(scores, bins = 10,
                color = "lightgreen",
                edgecolor = "#000000")

plt.title("Scores")
plt.xlabel("Score")
plt.ylabel("# of Students")

plt.show()

# %% [markdown]
# ### Subplots

# %%
# Figure => The Entire Canvas
# Ax = A single plot (subplot)

x = np.array([1, 2, 3, 4, 5])

figure, axes = plt.subplots(2,2)


axes[0, 0].plot(x, 2*x + 3, color = "#444444A3")
axes[0, 0].set_title("Linear Equation")

axes[0, 1].plot(x, (7*x**2)/2, color = "#FFBE4E")
axes[0, 1].set_title("Quadratic Equation")

axes[1, 0].plot(x, (x**3) + 9, color = "#ff5bc0")
axes[1, 0].set_title("Cubic Equation")

axes[1, 1].plot(x, (x**4) - 20, color = "#63fe6b")
axes[1, 1].set_title("Quintic Equation")


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matplotlib and Pandas

# %%
df = pd.read_csv("data/pokemon.csv")

# %%
# Alternative Method of finding the number occurance of each category

pokemonNames = (df['Type1'].unique())
pokeSums = []

for pokemon in pokemonNames:
    sum = 0
    for name in df['Type1']:
        if(pokemon == name):
            sum += 1
    pokeSums.append({pokemon: sum})

pokeSums
# Out:
# [{'Grass': 15},
#  {'Fire': 14},
#  {'Water': 28},
#  {'Bug': 12},
#  {'Normal': 22},
#  {'Poison': 14},
#  {'Electric': 9},
#  {'Ground': 8},
#  {'Fairy': 2},
#  {'Fighting': 7},
#  {'Psychic': 7},
#  {'Rock': 9},
#  {'Ghost': 3},
#  {'Ice': 2},
#  {'Dragon': 3}]

# %%
print(df['Type1'].value_counts())
# Out:
# Type1
# Water       28
# Normal      22
# Grass       15
# Fire        14
# Poison      14
# Bug         12
# Electric     9
# Rock         9
# Ground       8
# Fighting     7
# Psychic      7
# Ghost        3
# Dragon       3
# Fairy        2
# Ice          2
# Name: count, dtype: int64

# %%
type_count = df["Type1"].value_counts(ascending=True)


print(type_count.index) # list of indexes
print(type_count.values) # list of values
# Out:
# Index(['Fairy', 'Ice', 'Ghost', 'Dragon', 'Fighting', 'Psychic', 'Ground',
#        'Electric', 'Rock', 'Bug', 'Fire', 'Poison', 'Grass', 'Normal',
#        'Water'],
#       dtype='str', name='Type1')
# [ 2  2  3  3  7  7  8  9  9 12 14 14 15 22 28]

# %%
plt.barh(type_count.index, 
         type_count.values, 
         color = "#777777",
         edgecolor = "#000000")

plt.title("# of Pokemon by Primary Type")
plt.xlabel("No. of Pokemons")
plt.ylabel("Type")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### Dataset

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
titanic = sns.load_dataset("titanic")
planets = sns.load_dataset("planets")

# %% [markdown]
# ### Scatterplot

# %%
sns.scatterplot(x = "tip", y = "total_bill", 
                            data=tips, 
                            hue = "sex", 
                            size = "size", 
                            palette = "YlGnBu")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ### Histogram

# %%
sns.histplot(tips['tip'], kde=True, bins = 15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### Barplot

# %%
sns.barplot(tips['sex'])
# Out:
# <Axes: ylabel='sex'>

# %%
sns.barplot(x = 'sex', y = 'tip', 
            data = tips, 
            palette = "YlGnBu", 
            hue = "smoker")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# ### Box-Plot

# %%
sns.boxplot(y = "total_bill", data = tips, palette = "YlGnBu", hue = "day")
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(y = "total_bill", data = tips, palette = "YlGnBu", hue = "size")
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# ### Strip-Plot

# %%
sns.stripplot(x = "day", y = "tip", data = tips, dodge = True, palette = "YlGnBu", hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ### Joint-Plot

# %%
sns.jointplot(x = "tip", y = "total_bill", data = tips, hue="sex", palette = "YlGnBu")

# %%
sns.jointplot(x = "tip", y = "total_bill", data = tips, kind = "kde", cmap = "YlGnBu", fill = True)

# %%
sns.jointplot(x = "tip", y = "total_bill", data = tips, kind = "hex", cmap = "YlGnBu")

# %% [markdown]
# ### Pair-Plot

# %%
print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_numeric_df = titanic.select_dtypes(['number'])
sns.pairplot(titanic_numeric_df[['survived', 'age', 'pclass', 'fare']], hue = "pclass")

# %% [markdown]
# ### Heat Map

# %%
titanic_corr = titanic_numeric_df.corr()
print(titanic_corr)
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(titanic_corr, cmap="icefire", annot = True) #cmap => coolwarm, YlGnBu, icefire
# Out:
# <Axes: >

# %% [markdown]
# ### Cluster Map

# %%
iris_numeric = iris.select_dtypes(["number"])
print(iris_numeric)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.clustermap(iris_numeric)
